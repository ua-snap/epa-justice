# %%
import pandas as pd

# %%
# load "original" NCR - census lookup table.... it's been slightly modified:
# a number of communities already in GVV were missing from this table and so were added manually
# king cove, chignik, craig, port protection, gambell, elfin cove, klawock, metlakatla
tbl = pd.read_csv('/Users/joshpaul/epa-justice/repo/epa-justice/tbl/NCRPlaces_Census.csv')
# drop any rows without an ID ... these are the rows of places to add to NCR, 
# which have been processed separately and will be added later in this notebook
tbl = tbl[~tbl['id'].isna()]
# also drop any rows with no GEOIDFQ ... these are places with no equivalent census area assigned
tbl = tbl[~tbl['GEOIDFQ'].isna()]

# %%
tbl.sort_values(by=['id'])
# Out:
#        id                               name         alt_name  region country  \
# 42    AK1                            Afognak         Agw’aneq  Alaska      US
# 44  AK100                          Dry Creek              NaN  Alaska      US
# 45  AK102                              Eagle  Tthee T'äwdlenn  Alaska      US
# 47  AK104                      Eagle Village              NaN  Alaska      US
# 48  AK105                           Edna Bay              NaN  Alaska      US
# ..    ...                                ...              ...     ...     ...
# 24  CENS5               Kusilvak Census Area              NaN     NaN     NaN
# 25  CENS6                   Nome Census Area              NaN     NaN     NaN
# 26  CENS7  Prince of Wales-Hyder Census Area              NaN     NaN     NaN
# 27  CENS8          Yukon-Koyukuk Census Area              NaN     NaN     NaN
# 28  CENS9                 Bethel Census Area              NaN     NaN     NaN
#
#     latitude  longitude         type           GEOIDFQ  \
# 42   58.0078   -152.768    community  1600000US0201560
# 44   63.7000   -144.567    community  1600000US0220020
# 45   64.7880   -141.200    community  1600000US0220380
# 47   64.7805   -141.114    community  1600000US0220600
# 48   55.9489   -133.662    community  1600000US0220970
# ..       ...        ...          ...               ...
# 24       NaN        NaN  census_area    0500000US02158
# 25       NaN        NaN  census_area    0500000US02180
# 26       NaN        NaN  census_area    0500000US02198
# 27       NaN        NaN  census_area    0500000US02290
# 28       NaN        NaN  census_area    0500000US02050
#
#                             PLACENAME                 AREATYPE COMMENT
# 42                        Aleneva CDP  Census designated place     NaN
# 44                      Dry Creek CDP  Census designated place     NaN
# 45                         Eagle city       Incorporated place     NaN
# 47                  Eagle Village CDP  Census designated place     NaN
# 48                      Edna Bay city       Incorporated place     NaN
# ..                                ...                      ...     ...
# 24               Kusilvak Census Area                   County     NaN
# 25                   Nome Census Area                   County     NaN
# 26  Prince of Wales-Hyder Census Area                   County     NaN
# 27          Yukon-Koyukuk Census Area                   County     NaN
# 28                 Bethel Census Area                   County     NaN
#
# [309 rows x 12 columns]

# %%
# load new NCR - census lookup table
# this table was created by manually identifying coordinates for places not found in NCR, but desired for their census data
# Adak and Eareckson Station are not included, because no NCR data is available
to_add = pd.read_csv('/Users/joshpaul/epa-justice/repo/epa-justice/tbl/new_NCRPlaces_Census.csv')
# remove Adak and Eareckson Station from this list, since their coordinates do not return any data in NCR
droplist = ["Adak", "Eareckson Station"]
to_add = to_add[~to_add['name'].isin(droplist)]

# we also need to load the GVV community table to get IDs
# right now we load from dev branch:
gvv = pd.read_csv('https://raw.githubusercontent.com/ua-snap/geospatial-vector-veracity/epa-justice/vector_data/point/alaska_point_locations.csv')
# this should be on the main branch soon, so this URL will need to be updated to:
# https://raw.githubusercontent.com/ua-snap/geospatial-vector-veracity/main/vector_data/point/alaska_point_locations.csv

# %%
# look up the new GVV ids and populate the to_add table with them
for index, row in to_add.iterrows():
    id = gvv[gvv['name'] == row['name']]['id'].values[0]
    to_add.at[index, 'id'] = id

to_add
# Out:
# /var/folders/dz/1ccfqg_n5mg3fsrt8rwm7fd80000gn/T/ipykernel_32396/3713597822.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'AK487' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   to_add.at[index, 'id'] = id
#        id                     name alt_name  region country   latitude  \
# 0   AK487                  Susitna      NaN  Alaska      US  61.578610
# 2   AK488             Alcan Border      NaN  Alaska      US  62.685631
# 3   AK489                  Aleneva      NaN  Alaska      US  58.004623
# 4   AK490                   Badger      NaN  Alaska      US  64.805794
# 5   AK491               Bear Creek      NaN  Alaska      US  60.183879
# ..    ...                      ...      ...     ...     ...        ...
# 67  AK552                  Tolsona      NaN  Alaska      US  62.099027
# 68  AK553            Trapper Creek      NaN  Alaska      US  62.311386
# 69  AK554               Whitestone      NaN  Alaska      US  64.153587
# 70  AK555  Whitestone Logging Camp      NaN  Alaska      US  58.083142
# 71  AK556             Willow Creek      NaN  Alaska      US  61.812309
#
#      longitude       type           GEOIDFQ                    PLACENAME  \
# 0  -150.609051  community  1600000US0274340                  Susitna CDP
# 2  -141.125333  community  1600000US0201390             Alcan Border CDP
# 3  -152.882483  community  1600000US0201560                  Aleneva CDP
# 4  -147.403888  community  1600000US0205000                   Badger CDP
# 5  -149.388613  community  1600000US0205585               Bear Creek CDP
# ..         ...        ...               ...                          ...
# 67 -146.044410  community  1600000US0278297                  Tolsona CDP
# 68 -150.245805  community  1600000US0278680            Trapper Creek CDP
# 69 -145.886317  community  1600000US0284120               Whitestone CDP
# 70 -135.436672  community  1600000US0284200  Whitestone Logging Camp CDP
# 71 -145.194416  community  1600000US0285290             Willow Creek CDP
#
#                    AREATYPE COMMENT
# 0   Census designated place     NaN
# 2   Census designated place     NaN
# 3   Census designated place     NaN
# 4   Census designated place     NaN
# 5   Census designated place     NaN
# ..                      ...     ...
# 67  Census designated place     NaN
# 68  Census designated place     NaN
# 69  Census designated place     NaN
# 70  Census designated place     NaN
# 71  Census designated place     NaN
#
# [70 rows x 12 columns]

# %%
# concatenate the additional places to the original table
df = pd.concat([tbl, to_add])
df
# Out:
#         id                          name alt_name  region country   latitude  \
# 0    BORO1        Aleutians East Borough      NaN     NaN     NaN        NaN
# 1   BORO10     City and Borough of Sitka      NaN     NaN     NaN        NaN
# 2   BORO11            Petersburg Borough      NaN     NaN     NaN        NaN
# 3   BORO12  City and Borough of Wrangell      NaN     NaN     NaN        NaN
# 4   BORO13     Matanuska-Susitna Borough      NaN     NaN     NaN        NaN
# ..     ...                           ...      ...     ...     ...        ...
# 67   AK552                       Tolsona      NaN  Alaska      US  62.099027
# 68   AK553                 Trapper Creek      NaN  Alaska      US  62.311386
# 69   AK554                    Whitestone      NaN  Alaska      US  64.153587
# 70   AK555       Whitestone Logging Camp      NaN  Alaska      US  58.083142
# 71   AK556                  Willow Creek      NaN  Alaska      US  61.812309
#
#      longitude       type           GEOIDFQ                    PLACENAME  \
# 0          NaN    borough    0500000US02013       Aleutians East Borough
# 1          NaN    borough    0500000US02220       Sitka City and Borough
# 2          NaN    borough    0500000US02195           Petersburg Borough
# 3          NaN    borough    0500000US02275    Wrangell City and Borough
# 4          NaN    borough    0500000US02170    Matanuska-Susitna Borough
# ..         ...        ...               ...                          ...
# 67 -146.044410  community  1600000US0278297                  Tolsona CDP
# 68 -150.245805  community  1600000US0278680            Trapper Creek CDP
# 69 -145.886317  community  1600000US0284120               Whitestone CDP
# 70 -135.436672  community  1600000US0284200  Whitestone Logging Camp CDP
# 71 -145.194416  community  1600000US0285290             Willow Creek CDP
#
#                    AREATYPE COMMENT
# 0                    County     NaN
# 1                    County     NaN
# 2                    County     NaN
# 3                    County     NaN
# 4                    County     NaN
# ..                      ...     ...
# 67  Census designated place     NaN
# 68  Census designated place     NaN
# 69  Census designated place     NaN
# 70  Census designated place     NaN
# 71  Census designated place     NaN
#
# [379 rows x 12 columns]

# %%
# check for errors

# dups?
print(any(df['id'].duplicated()))
print(any(df['name'].duplicated()))
# nans?
print(any(df['id'].isna()))
print(any(df['name'].isna()))
# Out:
# False
# False
# False
# False

# %%
# save to CSV
# this CSV will need additional multi-row entries for Fairbanks, Anchorage, Juneau, etc 
# where there will be multiple GEOIDS per place - these may contain ZCTAs
# this CSV will also need additional single-row entries for certain communities with special situations (Eagle River, Sitka, etc)

df.to_csv('tbl/geoid_lookup.csv', index=False)
