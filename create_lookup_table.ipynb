# %%
import pandas as pd

# %%
# load "original" NCR - census lookup table.... it's been slightly modified:
# a number of communities already in GVV were missing from this table and so were added manually
# king cove, chignik, craig, port protection, gambell, elfin cove, klawock, metlakatla
tbl = pd.read_csv('/Users/joshpaul/epa-justice/repo/epa-justice/tbl/NCRPlaces_Census.csv')
# drop any rows without an ID ... these are the rows of places to add to NCR, 
# which have been processed separately and will be added later in this notebook
tbl = tbl[~tbl['id'].isna()]
# also drop any rows with no GEOIDFQ ... these are places with no equivalent census area assigned
tbl = tbl[~tbl['GEOIDFQ'].isna()]

# %%
tbl.sort_values(by=['id'])
# Out:
#        id                               name         alt_name  region country  \
# 42    AK1                            Afognak         Agw’aneq  Alaska      US
# 44  AK100                          Dry Creek              NaN  Alaska      US
# 45  AK102                              Eagle  Tthee T'äwdlenn  Alaska      US
# 47  AK104                      Eagle Village              NaN  Alaska      US
# 48  AK105                           Edna Bay              NaN  Alaska      US
# ..    ...                                ...              ...     ...     ...
# 24  CENS5               Kusilvak Census Area              NaN     NaN     NaN
# 25  CENS6                   Nome Census Area              NaN     NaN     NaN
# 26  CENS7  Prince of Wales-Hyder Census Area              NaN     NaN     NaN
# 27  CENS8          Yukon-Koyukuk Census Area              NaN     NaN     NaN
# 28  CENS9                 Bethel Census Area              NaN     NaN     NaN
#
#     latitude  longitude         type           GEOIDFQ  \
# 42   58.0078   -152.768    community  1600000US0201560
# 44   63.7000   -144.567    community  1600000US0220020
# 45   64.7880   -141.200    community  1600000US0220380
# 47   64.7805   -141.114    community  1600000US0220600
# 48   55.9489   -133.662    community  1600000US0220970
# ..       ...        ...          ...               ...
# 24       NaN        NaN  census_area    0500000US02158
# 25       NaN        NaN  census_area    0500000US02180
# 26       NaN        NaN  census_area    0500000US02198
# 27       NaN        NaN  census_area    0500000US02290
# 28       NaN        NaN  census_area    0500000US02050
#
#                             PLACENAME                 AREATYPE COMMENT
# 42                        Aleneva CDP  Census designated place     NaN
# 44                      Dry Creek CDP  Census designated place     NaN
# 45                         Eagle city       Incorporated place     NaN
# 47                  Eagle Village CDP  Census designated place     NaN
# 48                      Edna Bay city       Incorporated place     NaN
# ..                                ...                      ...     ...
# 24               Kusilvak Census Area                   County     NaN
# 25                   Nome Census Area                   County     NaN
# 26  Prince of Wales-Hyder Census Area                   County     NaN
# 27          Yukon-Koyukuk Census Area                   County     NaN
# 28                 Bethel Census Area                   County     NaN
#
# [302 rows x 12 columns]

# %%
# load new NCR - census lookup table
# this table was created by manually identifying coordinates for places not found in NCR, but desired for their census data
# Adak and Eareckson Station were not included, because no NCR data is available
to_add = pd.read_csv('/Users/joshpaul/epa-justice/repo/epa-justice/tbl/new_NCRPlaces_Census.csv')

# we also need to load the GVV community table to get IDs
# this should be on the main branch soon, so this URL may need to be updated
gvv = pd.read_csv('https://raw.githubusercontent.com/ua-snap/geospatial-vector-veracity/epa-justice/vector_data/point/alaska_point_locations.csv')

# %%
for index, row in to_add.iterrows():
    print(gvv[gvv['name'] == row['name']]['name'].values)
    print(gvv[gvv['name'] == row['name']]['id'].values)
# Out:
# ['Susitna']
# ['AK487']
# []
# []
# ['Alcan Border']
# ['AK488']
# ['Aleneva']
# ['AK489']
# ['Badger']
# ['AK490']
# ['Bear Creek']
# ['AK491']
# ['Beluga']
# ['AK492']
# ['Buffalo Soapstone']
# ['AK493']
# ['Butte']
# ['AK494']
# ['Chase']
# ['AK495']
# ['Chena Ridge']
# ['AK496']
# ['Chignik' 'Chignik']
# ['AK497' 'AK67']
# ['Coldfoot']
# ['AK498']
# ['Covenant Life']
# ['AK499']
# ['Craig' 'Craig']
# ['AK91' 'AK500']
# ['Crown Point']
# ['AK501']
# ['Deltana']
# ['AK502']
# ['Denali Park']
# ['AK503']
# ['Diamond Ridge']
# ['AK504']
# ['Dot Lake Village']
# ['AK505']
# []
# []
# ['Elfin Cove' 'Elfin Cove']
# ['AK114' 'AK506']
# ['Eureka Roadhouse']
# ['AK507']
# ['Evansville']
# ['AK508']
# ['Farm Loop']
# ['AK509']
# ['Farmers Loop']
# ['AK510']
# ['Fishhook']
# ['AK511']
# ['Four Mile Road']
# ['AK512']
# ['Fox River']
# ['AK513']
# ['Fritz Creek']
# ['AK514']
# ['Funny River']
# ['AK515']
# ['Gambell' 'Gambell']
# ['AK516' 'AK134']
# ['Game Creek']
# ['AK517']
# ['Gateway']
# ['AK518']
# ['Glacier View']
# ['AK519']
# ['Goldstream']
# ['AK520']
# ['Halibut Cove']
# ['AK521']
# ['Happy Valley']
# ['AK522']
# ['Harding-Birch Lakes']
# ['AK523']
# ['Hobart Bay']
# ['AK524']
# ['Klawock' 'Klawock']
# ['AK525' 'AK200']
# ['Knik River']
# ['AK526']
# ['Kodiak Station']
# ['AK527']
# ['Lake Louise']
# ['AK528']
# ['Lazy Mountain']
# ['AK529']
# ['Lowell Point']
# ['AK530']
# ['Lutak']
# ['AK531']
# ['Meadow Lakes']
# ['AK532']
# ['Mertarvik']
# ['AK533']
# ['Metlakatla' 'Metlakatla']
# ['AK534' 'AK248']
# ['Mill Bay']
# ['AK535']
# ['Moose Creek']
# ['AK536']
# ['Mosquito Lake']
# ['AK537']
# ['Mud Bay']
# ['AK538']
# ['Naukati Bay']
# ['AK539']
# ['North Lakes']
# ['AK540']
# ['Pleasant Valley']
# ['AK541']
# ['Point MacKenzie']
# ['AK542']
# ['Point Possession']
# ['AK543']
# ['Pope-Vannoy Landing']
# ['AK544']
# ['Port Clarence']
# ['AK545']
# ['Port Protection' 'Port Protection']
# ['AK546' 'AK327']
# ['Primrose']
# ['AK547']
# ['Red Dog Mine']
# ['AK548']
# ['Ridgeway']
# ['AK549']
# ['Seldovia Village']
# ['AK550']
# ['Silver Springs']
# ['AK551']
# ['South Lakes']
# ['AK552']
# ['South Van Horn']
# ['AK553']
# ['St. George']
# ['AK554']
# ['Steele Creek']
# ['AK555']
# ['Susitna North']
# ['AK556']
# ['Sutton-Alpine']
# ['AK557']
# ['Tanaina']
# ['AK558']
# ['Tolsona']
# ['AK559']
# ['Trapper Creek']
# ['AK560']
# ['Whitestone']
# ['AK561']
# ['Whitestone Logging Camp']
# ['AK562']
# ['Willow Creek']
# ['AK563']
